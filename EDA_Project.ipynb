# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
import mysql.connector
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
Sales=pd.read_csv('C:/Users/bhuva/OneDrive/Desktop/EDA_Dataset/Sales.csv')
Stores=pd.read_csv('C:/Users/bhuva/OneDrive/Desktop/EDA_Dataset/Stores.csv')
Products=pd.read_csv('C:/Users/bhuva/OneDrive/Desktop/EDA_Dataset/Products.csv')
Customers=pd.read_csv('C:/Users/bhuva/OneDrive/Desktop/EDA_Dataset/Customers.csv',encoding='ISO-8859-1')
Exchange_Rate=pd.read_csv('C:/Users/bhuva/OneDrive/Desktop/EDA_Dataset/Exchange_Rates.csv')

# %%
Sales
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1   1/1/2016           NaN       265598
# 1            366001          1   1/1/2016     1/13/2016      1269051
# 2            366001          2   1/1/2016     1/13/2016      1269051
# 3            366002          1   1/1/2016     1/12/2016       266019
# 4            366002          2   1/1/2016     1/12/2016       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1  2/20/2021           NaN      1216913
# 62880       2243031          1  2/20/2021     2/24/2021       511229
# 62881       2243032          1  2/20/2021     2/23/2021       331277
# 62882       2243032          2  2/20/2021     2/23/2021       331277
# 62883       2243032          3  2/20/2021     2/23/2021       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# ...

# %%
Stores
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            NaN
#
#     Open Date
# 0    1/1/2008
# 1   1/12/2008
# 2    1/7/2012
# 3    1/1/2010
# ...

# %%
Products
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color Unit Cost USD Unit Price USD  SubcategoryKey  \
# ...

# %%
Customers
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
Exchange_Rate
# Out:
#             Date Currency  Exchange
# 0       1/1/2015      USD    1.0000
# 1       1/1/2015      CAD    1.1583
# 2       1/1/2015      AUD    1.2214
# 3       1/1/2015      EUR    0.8237
# 4       1/1/2015      GBP    0.6415
# ...          ...      ...       ...
# 11210  2/20/2021      USD    1.0000
# 11211  2/20/2021      CAD    1.2610
# 11212  2/20/2021      AUD    1.2723
# 11213  2/20/2021      EUR    0.8238
# 11214  2/20/2021      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
#Checking Sales Data
Sales
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1   1/1/2016           NaN       265598
# 1            366001          1   1/1/2016     1/13/2016      1269051
# 2            366001          2   1/1/2016     1/13/2016      1269051
# 3            366002          1   1/1/2016     1/12/2016       266019
# 4            366002          2   1/1/2016     1/12/2016       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1  2/20/2021           NaN      1216913
# 62880       2243031          1  2/20/2021     2/24/2021       511229
# 62881       2243032          1  2/20/2021     2/23/2021       331277
# 62882       2243032          2  2/20/2021     2/23/2021       331277
# 62883       2243032          3  2/20/2021     2/23/2021       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# ...

# %%
Sales.isnull().sum()
# Out:
# Order Number         0
# Line Item            0
# Order Date           0
# Delivery Date    49719
# CustomerKey          0
# StoreKey             0
# ProductKey           0
# Quantity             0
# Currency Code        0
# dtype: int64

# %%
(Sales.isnull().sum()/len(Sales))*100
# Out:
# Order Number      0.000000
# Line Item         0.000000
# Order Date        0.000000
# Delivery Date    79.064627
# CustomerKey       0.000000
# StoreKey          0.000000
# ProductKey        0.000000
# Quantity          0.000000
# Currency Code     0.000000
# dtype: float64

# %%
#Delivery Date Contains Null Values more than 79% its better to drop the Column
Sales.drop('Delivery Date',axis=1,inplace=True)

# %%
Sales
# Out:
#        Order Number  Line Item Order Date  CustomerKey  StoreKey  ProductKey  \
# 0            366000          1   1/1/2016       265598        10        1304
# 1            366001          1   1/1/2016      1269051         0        1048
# 2            366001          2   1/1/2016      1269051         0        2007
# 3            366002          1   1/1/2016       266019         0        1106
# 4            366002          2   1/1/2016       266019         0         373
# ...             ...        ...        ...          ...       ...         ...
# 62879       2243030          1  2/20/2021      1216913        43         632
# 62880       2243031          1  2/20/2021       511229         0          98
# 62881       2243032          1  2/20/2021       331277         0        1613
# 62882       2243032          2  2/20/2021       331277         0        1717
# 62883       2243032          3  2/20/2021       331277         0         464
#
#        Quantity Currency Code
# ...

# %%
Sales.dtypes
# Out:
# Order Number      int64
# Line Item         int64
# Order Date       object
# CustomerKey       int64
# StoreKey          int64
# ProductKey        int64
# Quantity          int64
# Currency Code    object
# dtype: object

# %%
Sales['Order Date'] = pd.to_datetime(Sales['Order Date'])

# %%
Sales
# Out:
#        Order Number  Line Item Order Date  CustomerKey  StoreKey  ProductKey  \
# 0            366000          1 2016-01-01       265598        10        1304
# 1            366001          1 2016-01-01      1269051         0        1048
# 2            366001          2 2016-01-01      1269051         0        2007
# 3            366002          1 2016-01-01       266019         0        1106
# 4            366002          2 2016-01-01       266019         0         373
# ...             ...        ...        ...          ...       ...         ...
# 62879       2243030          1 2021-02-20      1216913        43         632
# 62880       2243031          1 2021-02-20       511229         0          98
# 62881       2243032          1 2021-02-20       331277         0        1613
# 62882       2243032          2 2021-02-20       331277         0        1717
# 62883       2243032          3 2021-02-20       331277         0         464
#
#        Quantity Currency Code
# ...

# %%
Sales.dtypes
# Out:
# Order Number              int64
# Line Item                 int64
# Order Date       datetime64[ns]
# CustomerKey               int64
# StoreKey                  int64
# ProductKey                int64
# Quantity                  int64
# Currency Code            object
# dtype: object

# %%
#Checking Stores Data
Stores
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            NaN
#
#     Open Date
# 0    1/1/2008
# 1   1/12/2008
# 2    1/7/2012
# 3    1/1/2010
# ...

# %%
Stores.isnull().sum()
# Out:
# StoreKey         0
# Country          0
# State            0
# Square Meters    1
# Open Date        0
# dtype: int64

# %%
Stores.fillna('0',inplace=True)

# %%
Stores.dtypes
# Out:
# StoreKey          int64
# Country          object
# State            object
# Square Meters    object
# Open Date        object
# dtype: object

# %%
Stores['Open Date']=pd.to_datetime(Stores['Open Date'])

# %%
Stores
# Out:
#     StoreKey        Country                         State Square Meters  \
# 0          1      Australia  Australian Capital Territory         595.0
# 1          2      Australia            Northern Territory         665.0
# 2          3      Australia               South Australia        2000.0
# 3          4      Australia                      Tasmania        2000.0
# 4          5      Australia                      Victoria        2000.0
# ..       ...            ...                           ...           ...
# 62        63  United States                          Utah        2000.0
# 63        64  United States                 Washington DC        1330.0
# 64        65  United States                 West Virginia        1785.0
# 65        66  United States                       Wyoming         840.0
# 66         0         Online                        Online             0
#
#     Open Date
# 0  2008-01-01
# 1  2008-01-12
# 2  2012-01-07
# 3  2010-01-01
# 4  2015-12-09
# ...

# %%
Stores.dtypes
# Out:
# StoreKey                  int64
# Country                  object
# State                    object
# Square Meters            object
# Open Date        datetime64[ns]
# dtype: object

# %%
Stores['Country']=Stores['Country'].astype(str)
Stores['State']=Stores['State'].astype(str)

# %%
Stores.dtypes
# Out:
# StoreKey                  int64
# Country                  object
# State                    object
# Square Meters            object
# Open Date        datetime64[ns]
# dtype: object

# %%
Stores['Square Meters']=Stores['Square Meters'].astype(float)

# %%
Stores.dtypes
# Out:
# StoreKey                  int64
# Country                  object
# State                    object
# Square Meters           float64
# Open Date        datetime64[ns]
# dtype: object

# %%
Stores.isnull().sum()
# Out:
# StoreKey         0
# Country          0
# State            0
# Square Meters    0
# Open Date        0
# dtype: int64

# %%
Stores
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            0.0
#
#     Open Date
# 0  2008-01-01
# 1  2008-01-12
# 2  2012-01-07
# 3  2010-01-01
# ...

# %%
#Checking Products Data
Products
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color Unit Cost USD Unit Price USD  SubcategoryKey  \
# ...

# %%
Products.isnull().sum()
# Out:
# ProductKey        0
# Product Name      0
# Brand             0
# Color             0
# Unit Cost USD     0
# Unit Price USD    0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# dtype: int64

# %%
Products.dtypes
# Out:
# ProductKey         int64
# Product Name      object
# Brand             object
# Color             object
# Unit Cost USD     object
# Unit Price USD    object
# SubcategoryKey     int64
# Subcategory       object
# CategoryKey        int64
# Category          object
# dtype: object

# %%
Products['Unit Cost USD']=Products['Unit Cost USD'].replace('[//$,]','',regex=True).astype(float)
Products['Unit Price USD']=Products['Unit Price USD'].replace('[//$,]','',regex=True).astype(float)

# %%
Products
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color  Unit Cost USD  Unit Price USD  SubcategoryKey  \
# ...

# %%
Products.dtypes
# Out:
# ProductKey          int64
# Product Name       object
# Brand              object
# Color              object
# Unit Cost USD     float64
# Unit Price USD    float64
# SubcategoryKey      int64
# Subcategory        object
# CategoryKey         int64
# Category           object
# dtype: object

# %%
#Checking Customers Data
Customers
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
Customers .isnull().sum()
# Out:
# CustomerKey     0
# Gender          0
# Name            0
# City            0
# State Code     10
# State           0
# Zip Code        0
# Country         0
# Continent       0
# Birthday        0
# dtype: int64

# %%
Customers['State Code']=Customers['State Code'].fillna(Customers['State Code'].mode()[0])

# %%
Customers.isnull().sum()
# Out:
# CustomerKey    0
# Gender         0
# Name           0
# City           0
# State Code     0
# State          0
# Zip Code       0
# Country        0
# Continent      0
# Birthday       0
# dtype: int64

# %%
Customers.dtypes
# Out:
# CustomerKey     int64
# Gender         object
# Name           object
# City           object
# State Code     object
# State          object
# Zip Code       object
# Country        object
# Continent      object
# Birthday       object
# dtype: object

# %%
Customers['Birthday']=pd.to_datetime(Customers['Birthday'])

# %%
Customers.dtypes
# Out:
# CustomerKey             int64
# Gender                 object
# Name                   object
# City                   object
# State Code             object
# State                  object
# Zip Code               object
# Country                object
# Continent              object
# Birthday       datetime64[ns]
# dtype: object

# %%
Customers
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
#Checking Exchange Rate Data
Exchange_Rate
# Out:
#             Date Currency  Exchange
# 0       1/1/2015      USD    1.0000
# 1       1/1/2015      CAD    1.1583
# 2       1/1/2015      AUD    1.2214
# 3       1/1/2015      EUR    0.8237
# 4       1/1/2015      GBP    0.6415
# ...          ...      ...       ...
# 11210  2/20/2021      USD    1.0000
# 11211  2/20/2021      CAD    1.2610
# 11212  2/20/2021      AUD    1.2723
# 11213  2/20/2021      EUR    0.8238
# 11214  2/20/2021      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
Exchange_Rate.isnull().sum()
# Out:
# Date        0
# Currency    0
# Exchange    0
# dtype: int64

# %%
Exchange_Rate.dtypes
# Out:
# Date         object
# Currency     object
# Exchange    float64
# dtype: object

# %%
Exchange_Rate['Date']=pd.to_datetime(Exchange_Rate['Date'])

# %%
Exchange_Rate.dtypes
# Out:
# Date        datetime64[ns]
# Currency            object
# Exchange           float64
# dtype: object

# %%
Exchange_Rate
# Out:
#             Date Currency  Exchange
# 0     2015-01-01      USD    1.0000
# 1     2015-01-01      CAD    1.1583
# 2     2015-01-01      AUD    1.2214
# 3     2015-01-01      EUR    0.8237
# 4     2015-01-01      GBP    0.6415
# ...          ...      ...       ...
# 11210 2021-02-20      USD    1.0000
# 11211 2021-02-20      CAD    1.2610
# 11212 2021-02-20      AUD    1.2723
# 11213 2021-02-20      EUR    0.8238
# 11214 2021-02-20      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
#Merging Customers Data with Sales Data
Overall=Sales

# %%
Overall
# Out:
#        Order Number  Line Item Order Date  CustomerKey  StoreKey  ProductKey  \
# 0            366000          1 2016-01-01       265598        10        1304
# 1            366001          1 2016-01-01      1269051         0        1048
# 2            366001          2 2016-01-01      1269051         0        2007
# 3            366002          1 2016-01-01       266019         0        1106
# 4            366002          2 2016-01-01       266019         0         373
# ...             ...        ...        ...          ...       ...         ...
# 62879       2243030          1 2021-02-20      1216913        43         632
# 62880       2243031          1 2021-02-20       511229         0          98
# 62881       2243032          1 2021-02-20       331277         0        1613
# 62882       2243032          2 2021-02-20       331277         0        1717
# 62883       2243032          3 2021-02-20       331277         0         464
#
#        Quantity Currency Code
# ...

# %%
Overall=pd.merge(Overall,Customers,on='CustomerKey',how='inner')

# %%
Overall
# Out:
#        Order Number  Line Item Order Date  CustomerKey  StoreKey  ProductKey  \
# 0            366000          1 2016-01-01       265598        10        1304
# 1            366001          1 2016-01-01      1269051         0        1048
# 2            366001          2 2016-01-01      1269051         0        2007
# 3            366002          1 2016-01-01       266019         0        1106
# 4            366002          2 2016-01-01       266019         0         373
# ...             ...        ...        ...          ...       ...         ...
# 62879       2243030          1 2021-02-20      1216913        43         632
# 62880       2243031          1 2021-02-20       511229         0          98
# 62881       2243032          1 2021-02-20       331277         0        1613
# 62882       2243032          2 2021-02-20       331277         0        1717
# 62883       2243032          3 2021-02-20       331277         0         464
#
# ...

# %%
Products
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color  Unit Cost USD  Unit Price USD  SubcategoryKey  \
# ...

# %%
Overall=pd.merge(Overall,Products,on='ProductKey',how='inner')

# %%
Overall
# Out:
#        Order Number  Line Item Order Date  CustomerKey  StoreKey  ProductKey  \
# 0            366000          1 2016-01-01       265598        10        1304
# 1            366001          1 2016-01-01      1269051         0        1048
# 2            366001          2 2016-01-01      1269051         0        2007
# 3            366002          1 2016-01-01       266019         0        1106
# 4            366002          2 2016-01-01       266019         0         373
# ...             ...        ...        ...          ...       ...         ...
# 62879       2243030          1 2021-02-20      1216913        43         632
# 62880       2243031          1 2021-02-20       511229         0          98
# 62881       2243032          1 2021-02-20       331277         0        1613
# 62882       2243032          2 2021-02-20       331277         0        1717
# 62883       2243032          3 2021-02-20       331277         0         464
#
# ...

# %%
Overall['Order Date'] = pd.to_datetime(Overall['Order Date'])
Exchange_Rate['Date'] = pd.to_datetime(Exchange_Rate['Date'])
Overall = pd.merge(Overall, Exchange_Rate, left_on=['Order Date', 'Currency Code'], right_on=['Date', 'Currency'], how='inner')

# %%
Overall
# Out:
#        Order Number  Line Item Order Date  CustomerKey  StoreKey  ProductKey  \
# 0            366000          1 2016-01-01       265598        10        1304
# 1            366001          1 2016-01-01      1269051         0        1048
# 2            366001          2 2016-01-01      1269051         0        2007
# 3            366002          1 2016-01-01       266019         0        1106
# 4            366002          2 2016-01-01       266019         0         373
# ...             ...        ...        ...          ...       ...         ...
# 62879       2243030          1 2021-02-20      1216913        43         632
# 62880       2243031          1 2021-02-20       511229         0          98
# 62881       2243032          1 2021-02-20       331277         0        1613
# 62882       2243032          2 2021-02-20       331277         0        1717
# 62883       2243032          3 2021-02-20       331277         0         464
#
# ...

# %%
Overall=pd.merge(Overall,Stores,on='StoreKey',how ='inner')

# %%
Overall
# Out:
#        Order Number  Line Item Order Date  CustomerKey  StoreKey  ProductKey  \
# 0            366000          1 2016-01-01       265598        10        1304
# 1            366001          1 2016-01-01      1269051         0        1048
# 2            366001          2 2016-01-01      1269051         0        2007
# 3            366002          1 2016-01-01       266019         0        1106
# 4            366002          2 2016-01-01       266019         0         373
# ...             ...        ...        ...          ...       ...         ...
# 62879       2243030          1 2021-02-20      1216913        43         632
# 62880       2243031          1 2021-02-20       511229         0          98
# 62881       2243032          1 2021-02-20       331277         0        1613
# 62882       2243032          2 2021-02-20       331277         0        1717
# 62883       2243032          3 2021-02-20       331277         0         464
#
# ...

# %%
Overall.isnull().sum()
# Out:
# Order Number      0
# Line Item         0
# Order Date        0
# CustomerKey       0
# StoreKey          0
# ProductKey        0
# Quantity          0
# Currency Code     0
# Gender            0
# Name              0
# City              0
# State Code        0
# State_x           0
# Zip Code          0
# Country_x         0
# Continent         0
# Birthday          0
# Product Name      0
# Brand             0
# Color             0
# Unit Cost USD     0
# Unit Price USD    0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# Date              0
# Currency          0
# Exchange          0
# Country_y         0
# State_y           0
# Square Meters     0
# Open Date         0
# dtype: int64

# %%
Overall
# Out:
#        Order Number  Line Item Order Date  CustomerKey  StoreKey  ProductKey  \
# 0            366000          1 2016-01-01       265598        10        1304
# 1            366001          1 2016-01-01      1269051         0        1048
# 2            366001          2 2016-01-01      1269051         0        2007
# 3            366002          1 2016-01-01       266019         0        1106
# 4            366002          2 2016-01-01       266019         0         373
# ...             ...        ...        ...          ...       ...         ...
# 62879       2243030          1 2021-02-20      1216913        43         632
# 62880       2243031          1 2021-02-20       511229         0          98
# 62881       2243032          1 2021-02-20       331277         0        1613
# 62882       2243032          2 2021-02-20       331277         0        1717
# 62883       2243032          3 2021-02-20       331277         0         464
#
# ...

# %%
col=list(Overall.columns)
col1=[]
for c in col:
    col1.append(c.replace(' ','_').lower())
Overall.columns=col1

# %%
col1
# Out:
# ['order_number',
#  'line_item',
#  'order_date',
#  'customerkey',
#  'storekey',
#  'productkey',
#  'quantity',
#  'currency_code',
#  'gender',
#  'name',
#  'city',
#  'state_code',
#  'state_x',
#  'zip_code',
#  'country_x',
#  'continent',
#  'birthday',
#  'product_name',
#  'brand',
#  'color',
#  'unit_cost_usd',
#  'unit_price_usd',
#  'subcategorykey',
#  'subcategory',
#  'categorykey',
#  'category',
#  'date',
#  'currency',
#  'exchange',
#  'country_y',
#  'state_y',
#  'square_meters',
#  'open_date']

# %%
Overall.to_csv('Overall.csv')

# %%
#Establishing connention to mysql
import pymysql
Connection=pymysql.connect(
    host='127.0.0.1',
    port=3306,
    user='root',
    password='Bhuvi#...3'
)
try:
    Cursor=Connection.cursor()
    database_name ="Dataspark"
    Cursor.execute(f"CREATE DATABASE {database_name}")
    print(f"database'{database_name}'created successfully!")

except pymysql.MySQLError as e:
    print(f"Error occured: {e}")

finally:
    Cursor.close()
    Connection.close()
# Out:
# database'Dataspark'created successfully!

# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine

host='127.0.0.1'
port=3306
user='root'
password='Bhuvi#...3'
database='Dataspark'

engine_string=f"mysql+pymysql://{user}:{password}@{host}:{port}/{database}"
engine=create_engine(engine_string)

table_name="overall"
Overall.to_sql(table_name,engine,if_exists='replace',index=False)
print(f"successfully imported {table_name} to SQL")

table_name="customers"
Customers.to_sql(table_name,engine,if_exists='replace',index=False)
print(f"successfully imported {table_name} to SQL")

table_name="products"
Products.to_sql(table_name,engine,if_exists='replace',index=False)
print(f"successfully imported {table_name} to SQL")

table_name="exchange_rate"
Exchange_Rate.to_sql(table_name,engine,if_exists='replace',index=False)
print(f"successfully imported {table_name} to SQL")

table_name="stores"
Stores.to_sql(table_name,engine,if_exists='replace',index=False)
print(f"successfully imported {table_name} to SQL")
# Out:
# successfully imported overall to SQL
# successfully imported customers to SQL
# successfully imported products to SQL
# successfully imported exchange_rate to SQL
# successfully imported stores to SQL
